# %% [markdown]
# # **Giới thiệu về R**
#
# * R là một ngôn ngữ dành cho tính toán và đồ họa thống kê.
# * R là một phần của dự án GNU Project
# * R có nguồn gốc từ S, được phát triển tại Bell Laboratories bởi John Chambers và các cộng sự.
# * R là phần mềm miễn phí, chạy được trên cả Windows, Linux, MacOS

# %% [markdown]
# # **Hướng dẫn cài đặt & sử dụng R**
#
# ## 1. Cài đặt R
#
# ### Windows
#
# 1. Truy cập: [https://cloud.r-project.org/](https://cloud.r-project.org/)
# 2. Chọn **Download R for Windows** → **base** → tải file `.exe`.
# 3. Chạy file cài đặt, chọn `Next` cho đến khi hoàn tất.
# 4. Mở **Command Prompt (cmd)** và gõ:
#
#    ```bash
#    R --version
#    ```
#
#    Nếu thấy thông báo như:
#
#    ```
#    R version 4.5.1 (2025-06-13 ucrt) -- "Great Square Root"
#    ```
#
#    thì đã cài đặt thành công.
#
# ---
#
# ### macOS
#
# 1. Truy cập: [https://cloud.r-project.org/](https://cloud.r-project.org/)
# 2. Chọn **Download R for macOS** → tải file `.pkg` (Intel hoặc Apple Silicon).
# 3. Chạy file `.pkg` và làm theo hướng dẫn.
# 4. Mở **Terminal** và gõ:
#
#    ```bash
#    R --version
#    ```
#
# ---
#
# ### Linux (Ubuntu/Debian)
#
# 1. Cập nhật hệ thống:
#
#    ```bash
#    sudo apt update && sudo apt upgrade -y
#    ```
# 2. Cài đặt R:
#
#    ```bash
#    sudo apt install r-base -y
#    ```
# 3. Kiểm tra:
#
#    ```bash
#    R --version
#    ```
#
# 👉 Với các bản phân phối khác (Fedora, Arch, …), thay `apt` bằng `dnf`, `yum`, hoặc `pacman`.
#
# ---
#
# ## 2. Sử dụng RStudio
#
# RStudio là IDE phổ biến cho R.
#
# ### Windows & macOS
#
# * Tải tại: [https://posit.co/download/rstudio-desktop/](https://posit.co/download/rstudio-desktop/)
# * Cài đặt như phần mềm bình thường (`Next` → `Finish`).
#
# ### Linux
#
# * Ubuntu/Debian:
#
#   ```bash
#   sudo apt install gdebi-core -y
#   wget https://download1.rstudio.org/electron/jammy/amd64/rstudio-2025.05.1-513-amd64.deb
#   sudo gdebi rstudio-2025.05.1-513-amd64.deb
#   ```
#
# ---
#
# ## 3. Sử dụng R trong VSCode
#
# 1. Cài [Visual Studio Code](https://code.visualstudio.com/).
# 2. Trong **Extensions (Ctrl+Shift+X)**, tìm và cài:
#
#    * **R Extension** (Yuki Ueda hoặc R Tools)
#    * **R LSP Client** (hỗ trợ code completion)
# 3. Cấu hình đường dẫn R:
#
#    * `r.rterm.windows` → `C:\\Program Files\\R\\R-4.5.1\\bin\\R.exe`
#    * `r.rterm.mac` hoặc `r.rterm.linux` → `/usr/bin/R`
# 4. Mở file `.R` và chạy thử:
#
#    ```R
#    print("Hello R in VSCode!")
#    ```
#
# ---
#
# ## 4. Sử dụng Kaggle Notebook
#
# Kaggle hỗ trợ sẵn môi trường R, không cần cài đặt thủ công.
#
# 1. Đăng nhập vào [Kaggle](https://www.kaggle.com/).
# 2. Vào mục **Code** → **New Notebook**.
# 3. Ở góc trên bên phải, chọn **Notebook Settings** → bật **R** làm ngôn ngữ mặc định (thay vì Python).
# 4. Chạy thử:
#
#    ```R
#    print("Hello R on Kaggle!")
#    ```
# 5. Có thể cài thêm package bằng:
#
#    ```R
#    install.packages("ggplot2")
#    library(ggplot2)
#    ```

# %% [markdown]
# # **Thực hiện chương trình R đầu tiên**
#
# ## Sử dụng R Studio
#
# 1. Mở ứng dụng **R Studio**.
#
#    ![image.png](../images/Chapter0/RStudio.png)
#
# 2. Ở góc trên bên trái, chọn **File** → **New Project** để tạo dự án mới, hoặc chọn **Open Project** để mở dự án đã có.
#
#    ![image-2.png](../images/Chapter0/RNewProject.png)
#
# 3. Trong cửa sổ hiện ra:
#
#    * Chọn **New Directory** → **New Project** để tạo một thư mục (folder) mới.
#    * Hoặc chọn **Existing Directory** để mở một thư mục đã có sẵn.
#
# 4. Nếu tạo thư mục mới, nhập **tên thư mục** (Directory name) và **địa chỉ lưu** (Create project as subdirectory of).
#
#    ![New Project](../images/Chapter0/New%20Project.png)
#
# 5. Sau khi tạo dự án, cửa sổ làm việc của bạn trong R Studio sẽ được mở sẵn trong thư mục dự án.
#    Ở **R Script** (bên trái trên), bạn có thể nhập chương trình R đầu tiên, ví dụ:
#
#    ```r
#    print("Hello R!")
#    ```
#
# 6. Để chạy chương trình, chọn dòng lệnh và nhấn **Ctrl + Enter** (Windows) hoặc **Cmd + Enter** (Mac).
#    Kết quả sẽ hiển thị ở cửa sổ **Console** phía dưới.
#
# ---
#
# ## Sử dụng VS Code
#
# 1. Mở ứng dụng **Visual Studio Code (VS Code)**.
#
# 2. Tạo một file mới với đuôi `.R`, ví dụ: `hello.R`.
#
# 3. Nhập nội dung:
#
#    ```r
#    print("Hello R from VS Code!")
#    ```
#
# 4. Lưu file và chạy bằng cách:
#
#    * Cài đặt R và cấu hình đường dẫn trong VS Code.
#    * Chạy trực tiếp bằng **Terminal** trong VS Code:
#
#      ```bash
#      Rscript hello.R
#      ```
#
#    Kết quả sẽ in ra trong terminal.
#
# 5. Hoặc nếu đã cài R extensions có thể bấm nút chạy trực tiếp
# ---
#
# ## Sử dụng Kaggle
#
# 1. Vào trang [Kaggle](https://www.kaggle.com/) và đăng nhập tài khoản.
#
# 2. Ở thanh menu, chọn **Code** → **New Notebook**.
#
# 3. Chọn **Language: R** để tạo notebook với môi trường R.
#
# 4. Trong ô code đầu tiên, nhập:
#
#    ```r
#    print("Hello R from Kaggle!")
#    ```
#
# 5. Nhấn **Run** (biểu tượng ▶) để chạy ô lệnh.
#    Kết quả sẽ hiển thị ngay bên dưới ô code.
